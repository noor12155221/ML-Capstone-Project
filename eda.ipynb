# %% [markdown]
# <a href="https://colab.research.google.com/github/noor12155221/ML-Capstone-Project/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello ml team")
# Out:
# hello ml team

# %%
nj m
